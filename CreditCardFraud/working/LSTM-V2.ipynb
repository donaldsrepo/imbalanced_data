# %% [markdown]
# some ideas: https://stackoverflow.com/questions/41488279/neural-network-always-predicts-the-same-class
#
# more ideas: https://www.tensorflow.org/tutorials/structured_data/imbalanced_data
# <pre>
#
# ---------------------- TODO --------------------------------------
#
# 1) normalize the train data before building the model using StandardScaler
#     maybe normalize the test dataset also?
#
# ---------------------- DONE --------------------------------------
# change the split and downsampling order
#
# now: start with an imbalanced dataset
#      downsample all the data to a small balanced subset
#      split and shape using stratify the small subset into 70/30 for Train/Test
#      means the Test dataset is also balanced
#
# want: start with imbalanced dataset
#       split using sklearn:train_test_split into 70/30 for Train/Test
#       downsample and shape the Train dataset to become balanced
#       shape the Test dataset
#       means the Test dataset is imbalanced as it should be

# %%
import os
colab = os.environ.get('COLAB_GPU', '10')
if (int(colab) == 0):
    from google.colab import drive
    drive.mount('/content/drive')  
else:
    print("")

# %%
# Check if Google Colab path exists
if os.path.exists("/content/drive/My Drive/MyDSNotebooks/Imbalanced_data/input/creditcardzip") :
    # Change the current working Directory    
    os.chdir("/content/drive/My Drive/MyDSNotebooks/Imbalanced_data/input/creditcardzip")
# else check if Kaggle/local path exists
elif os.path.exists("../input/creditcardzip") :
    # Change the current working Directory    
    os.chdir("../input/creditcardzip")
else:
    print("Can't change the Current Working Directory") 
print("Current Working Directory " , os.getcwd())

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers.recurrent import LSTM
from keras.layers import Embedding
#from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from keras import optimizers
from keras import initializers
from keras.optimizers import SGD
from keras.optimizers import RMSprop
from keras.optimizers import Adagrad
from keras.callbacks import EarlyStopping

a='''
# to try ---------------------------------------------
# snippet of using the LearningRateScheduler callback
from keras.callbacks import LearningRateScheduler
def my_learning_rate(epoch, lrate)
	return lrate 
lrs = LearningRateScheduler(my_learning_rate)
model.fit(..., callbacks=[lrs])

#or

# snippet of using the ReduceLROnPlateau callback
from keras.callbacks import ReduceLROnPlateau
...
rlrop = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=100)
model.fit(..., callbacks=[rlrop])'''

# -------------------------------------------------------
#initialize variables
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
cm_results = []
class_names=[0,1] # name  of classes 1=fraudulent transaction
# Out:
# Can't change the Current Working Directory
# Current Working Directory  C:\DataScience\Repo\Imbalanced_data\input\creditcardzip

# %%
def display_metrics(model_name, train_features, test_features, train_label, test_label, pred):
    try:
        print(model_name.score(test_features, test_label)) 
        print("Accuracy score (training): {0:.3f}".format(model_name.score(train_features, train_label))) 
        print("Accuracy score (validation): {0:.3f}".format(model_name.score(test_features, test_label))) 
    except Exception as e:
        print("error")  
    try:
        print(pd.Series(model_name.feature_importances_, index=train_features.columns[:]).nlargest(10).plot(kind='barh')) 
    except Exception as e:
        print("error")  
        
    print("Confusion Matrix:")
    tn, fp, fn, tp = confusion_matrix(test_label, pred).ravel()
    total = tn+ fp+ fn+ tp 
    print("false positive pct:",(fp/total)*100) 
    print("tn", " fp", " fn", " tp") 
    print(tn, fp, fn, tp) 
    print(confusion_matrix(test_label, pred)) 
    print("Classification Report") 
    print(classification_report(test_label, pred))
    print("Specificity =", tn/(tn+fp))
    print("Sensitivity =", tp/(tp+fn))
    return tn, fp, fn, tp

# %%
def CalcPct(df,title):
    unique_elements, counts_elements = np.unique(df, return_counts=True)
    calc_pct = round(counts_elements[1]/(counts_elements[0]+counts_elements[1]) * 100,6)
    print(title)
    print(np.asarray((unique_elements, counts_elements)))
    return calc_pct

# %%
def plot_loss(history, label, n):
    # Use a log scale to show the wide range of values.
    plt.semilogy(history.epoch,  history.history['loss'],
               color=colors[n], label='Train '+label)
    #plt.semilogy(history.epoch,  history.history['val_loss'],
    #      color=colors[n], label='Val '+label,
    #      linestyle="--")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend()

# %%
df = pd.read_csv('https://storage.googleapis.com/download.tensorflow.org/data/creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
#try some data cleansing

temp_df = df.copy()
temp_df = temp_df.drop(['Time'], axis=1)
temp_df['Log_Amount'] = np.log(temp_df.pop('Amount')+0.001)
df = temp_df.copy()

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Class  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053      0
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724      0
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458      0
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153      0
# ...          ...       ...       ...       ...       ...       ...    ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731      0
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527      0
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561      0
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533      0
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649      0
#
#         Log_Amount
# 0         5.008105
# 1         0.989913
# 2         5.936641
# 3         4.816249
# 4         4.248367
# ...            ...
# 284802   -0.260067
# 284803    3.210481
# 284804    4.217756
# 284805    2.302685
# 284806    5.379902
#
# [284807 rows x 30 columns]

# %%
X = df.loc[:, df.columns != 'Class']
y = df.loc[:, df.columns == 'Class']
OrigPct = CalcPct(y,"Original")

#print(y['Class'].value_counts())
# split the dataset
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = None, shuffle=True)

strat = True
if (strat == True):
    stratify=y['Class']
else:
    stratify="None"
# stratify will ensure that Train and Test get the same pct of minority classes (.17%)

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = None, shuffle=True, stratify=stratify)
TrainPct = CalcPct(y_train,"Train")

zeros, ones = np.bincount(y_train['Class'])
# Out:
# Original
# [[     0      1]
#  [284315    492]]
# Train
# [[     0      1]
#  [199020    344]]

# %%
# prepare the Train and Test data for the model. Need input to include arrays with certain shape

# downsample the Train data

# find the number of minority (value=1) samples in our dataset so we can down-sample our majority to it
yes = len(y_train[y_train['Class'] ==1])

# retrieve the indices of the minority and majority samples 
yes_ind = y_train[y_train['Class'] == 1].index
no_ind = y_train[y_train['Class'] == 0].index

# random sample the majority indices based on the amount of 
# minority samples
new_no_ind = np.random.choice(no_ind, yes, replace = False)

# merge the two indices together
undersample_ind = np.concatenate([new_no_ind, yes_ind])

# get undersampled dataframe from the merged indices of the dataset
X_train = X_train.loc[undersample_ind]
y_temp = y_train.loc[undersample_ind]
y_train_original = np.array(y_temp['Class'], dtype='int')
TrainDownPct = CalcPct(y_train_original,"TrainDownSampled")
y_test_original = np.array(y_test['Class'], dtype='int')
TestPct = CalcPct(y_test_original,"Test")

# normalize the features
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# handle any extreme fliers, set to 5 or -5
X_train = np.clip(X_train, -5, 5)
X_test = np.clip(X_test, -5, 5)

#shape the Train data 
rolling_window_size = 10  ### this selects how many historical transactions should be analyzed to judge the transaction at hand -- RNN width

X_train_interim = np.zeros([(X_train.shape[0]-rolling_window_size)*rolling_window_size,X_train.shape[1]]) # change 30 to a variable
y_train = []
for i in range((X_train.shape[0]-rolling_window_size)):
    beg = 0+i
    end = beg+rolling_window_size
    s = np.array(X_train[beg:end], dtype='float')
    X_train_interim[(rolling_window_size*i):(rolling_window_size*(i+1)),:] = s
    y_train.append(y_train_original[end])

y_train = np.array(y_train, dtype='int')
X_train_interim = X_train_interim[:,1::]

X_train_tensor = X_train_interim.reshape(int(np.shape(X_train_interim)[0]/rolling_window_size), rolling_window_size, np.shape(X_train_interim)[1])
X_train = X_train_tensor

#shape and split the Test data 

#X_test_interim = np.zeros([(X_test.shape[0]-rolling_window_size)*10,30])
X_test_interim = np.zeros([(X_test.shape[0]-rolling_window_size)*rolling_window_size,X_test.shape[1]])
y_test = []
for i in range((X_test.shape[0]-rolling_window_size)):
    beg = 0+i
    end = beg+rolling_window_size
    s = np.array(X_test[beg:end], dtype='float')
    X_test_interim[(rolling_window_size*i):(rolling_window_size*(i+1)),:] = s
    y_test.append(y_test_original[end]) 

y_test = np.array(y_test, dtype='int')
X_test_interim = X_test_interim[:,1::]

X_test_tensor = X_test_interim.reshape(int(np.shape(X_test_interim)[0]/rolling_window_size), rolling_window_size, np.shape(X_test_interim)[1])
X_test = X_test_tensor
# Out:
# TrainDownSampled
# [[  0   1]
#  [344 344]]
# Test
# [[    0     1]
#  [85295   148]]

# %%
# final data validation

# Form np arrays of labels and features.
a='''
train_labels = np.array(y_train)
bool_train_labels = train_labels != 0
test_labels = np.array(y_test)

train_features = np.array(X_train)
test_features = np.array(X_test)

pos_df = pd.DataFrame(train_features[ bool_train_labels], columns = X.columns)
neg_df = pd.DataFrame(train_features[~bool_train_labels], columns = X.columns)

sns.jointplot(pos_df['V5'], pos_df['V6'],
              kind='hex', xlim = (-5,5), ylim = (-5,5))
plt.suptitle("Positive distribution")

sns.jointplot(neg_df['V5'], neg_df['V6'],
              kind='hex', xlim = (-5,5), ylim = (-5,5))
_ = plt.suptitle("Negative distribution")'''

# %%
# run model

### Hyperparameters Tuning
# First test optimal epochs holding everything else constant
# Dropout: 0.1-0.6
# GradientClipping: 0.1-10
# BatchSize: 32,64,128,256,512 (power of 2)

# setting variables
lr = 0.025
w1 = 4.0
w2 = 1.0
epochs = 10000 # original was 200, also saw 100
batch_size = 4096 # original was 10000, also saw 2048
min_ = 0
max_ = 2
num_iter = 1

early_stopping = EarlyStopping(
    monitor='val_auc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

for w1 in np.linspace(1, 4, num = 1):
    for w2 in np.linspace(1, 4, num = 1):
        # keep lr constant at 0.01
        for lr in np.linspace(.01, .01, num=1):
            # repeat same settings for num of interations
            for n in np.linspace(0, 3, num=num_iter):
                ### Train LSTM using Keras 2 API ###
                model = Sequential()
                #model.add(LSTM(20, return_sequences=True, input_shape=X_train.shape[1:], kernel_initializer='lecun_uniform', activation='relu', kernel_regularizer=regularizers.l1(0.1), recurrent_regularizer=regularizers.l1(0.01), bias_regularizer=None, activity_regularizer=None, dropout=0.2, recurrent_dropout=0.2))#, return_sequences=True))
                #model.add(LSTM(20, return_sequences=True, input_shape=X_train.shape[1:], activation='relu', kernel_regularizer=regularizers.l1(0.1), recurrent_regularizer=regularizers.l1(0.01), bias_regularizer=None, activity_regularizer=None, dropout=0.2, recurrent_dropout=0.2))#, return_sequences=True))
                # defaults seem to work best, otherwise get very low score, AUC of 0.5 and all 0 or all 1 predictions
                model.add(LSTM(20, return_sequences=True, input_shape=X_train.shape[1:]))
                model.add(Dropout(0.2))
                model.add(LSTM(12, activation='relu', return_sequences=True))
                model.add(Dropout(0.2))
                model.add(LSTM(8, activation='relu', return_sequences=False)) # this is the last LSTM, so should return_sequences=False
                #model.add(Dense(1, kernel_initializer='lecun_uniform', activation='sigmoid'))
                model.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))
                # from https://www.tensorflow.org/tutorials/structured_data/imbalanced_data
                bias_initializer = ones/zeros # think this is just the ratio of minority/total, and so far the log() makes this worse
                #bias_initializer = np.log([bias_initializer])
                print('bias_initializer', bias_initializer)
                bias_initializer = initializers.Constant(bias_initializer)
                model.add(Dense(units=1, activation='sigmoid', bias_initializer=bias_initializer))
                #model.add(Dense(units=1, activation='sigmoid'))

                #optimizer = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False) # ValueError: None values not supported.

                optimizer = optimizers.Adam(lr=lr)

                #model.compile(loss='mean_squared_error', optimizer='adam')
                #model.compile(loss='mean_squared_error', optimizer=adam)
                #model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy']) #optimizer='rmsprop', optimizer='sgd', optimizer='adam'

                a='''
                lr_schedule = optimizers.schedules.ExponentialDecay(
                    initial_learning_rate=1e-2,
                    decay_steps=10000,
                    decay_rate=0.9)
                optimizer = optimizers.SGD(learning_rate=lr_schedule)'''

                #optimizer = optimizers.SGD(learning_rate=lr)
                #optimizer = optimizers.SGD(learning_rate=0.001, momentum=0.9,decay=0.01)

                model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy']) #optimizer='rmsprop', optimizer='sgd', optimizer='adam'
                
                results = model.evaluate(X_train, y_train, batch_size=batch_size, verbose=0)
                print("Initial Loss: {:0.4f}".format(results[0]))
                #print(model.summary())

                #model.fit(X_train, y_train, epochs=200, batch_size=10000, class_weight={0 : 1., 1: float(int(1/np.mean(y_train)))}, validation_split=0.3)
                #model.fit(X_train, y_train, epochs=4, batch_size=8)#, class_weight=np.where(y_train == 1,4.0,1.0).flatten() )
                model_output = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, class_weight=np.where(y_train == 1,w1,w2).flatten() )

                train_predict = model.predict_classes(X_train)
                test_predict = model.predict_classes(X_test)
                
                ### test AUC ###

                fpr, tpr, thresholds = metrics.roc_curve(y_train, train_predict, pos_label=1)
                print('TRAIN | AUC Score: ' + str((metrics.auc(fpr, tpr))))
                fpr, tpr, thresholds = metrics.roc_curve(y_test, test_predict, pos_label=1)
                print('TEST | AUC Score: ' + str((metrics.auc(fpr, tpr))))
                tn, fp, fn, tp = display_metrics(model, X_train, X_test, y_train, y_test, test_predict)
                cm_results.append([model.name, tn, fp, fn, tp, lr, w1, w2, epochs, batch_size])
                print('lr',lr,'w1',w1,'w2',w2,'epochs',epochs,'batch_size',batch_size)
                del model
# Out:
# bias_initializer 0.0017284695005527083
# Initial Loss: 0.6935
# Epoch 1/10000
# 678/678 [==============================] - 2s 3ms/step - loss: 0.6935 - accuracy: 0.5074
# Epoch 2/10000
# 678/678 [==============================] - 0s 50us/step - loss: 0.6933 - accuracy: 0.5074
# Epoch 3/10000
# 678/678 [==============================] - 0s 52us/step - loss: 0.6932 - accuracy: 0.5074
# Epoch 4/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.6930 - accuracy: 0.5074
# Epoch 5/10000
# 678/678 [==============================] - 0s 52us/step - loss: 0.6928 - accuracy: 0.5074
# Epoch 6/10000
# 678/678 [==============================] - 0s 52us/step - loss: 0.6926 - accuracy: 0.5074
# Epoch 7/10000
# 678/678 [==============================] - 0s 53us/step - loss: 0.6923 - accuracy: 0.5074
# Epoch 8/10000
# 678/678 [==============================] - 0s 53us/step - loss: 0.6918 - accuracy: 0.5074
# Epoch 9/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.6910 - accuracy: 0.5074
# Epoch 10/10000
# 678/678 [==============================] - 0s 52us/step - loss: 0.6894 - accuracy: 0.5074
# Epoch 11/10000
# 678/678 [==============================] - 0s 53us/step - loss: 0.6866 - accuracy: 0.5074
# Epoch 12/10000
# 678/678 [==============================] - 0s 52us/step - loss: 0.6825 - accuracy: 0.5074
# Epoch 13/10000
# 678/678 [==============================] - 0s 52us/step - loss: 0.6761 - accuracy: 0.5074
# Epoch 14/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.6714 - accuracy: 0.7316
# Epoch 15/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.6634 - accuracy: 0.9794
# Epoch 16/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.6549 - accuracy: 0.9941
# Epoch 17/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.6464 - accuracy: 0.9912
# Epoch 18/10000
# 678/678 [==============================] - 0s 127us/step - loss: 0.6431 - accuracy: 0.9882
# Epoch 19/10000
# 678/678 [==============================] - 0s 158us/step - loss: 0.6406 - accuracy: 0.9882
# Epoch 20/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.6382 - accuracy: 0.9882
# Epoch 21/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.6356 - accuracy: 0.9882
# Epoch 22/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.6331 - accuracy: 0.9882
# Epoch 23/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.6307 - accuracy: 0.9867
# Epoch 24/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.6279 - accuracy: 0.9882
# Epoch 25/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.6257 - accuracy: 0.9853
# Epoch 26/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.6228 - accuracy: 0.9867
# Epoch 27/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.6204 - accuracy: 0.9853
# Epoch 28/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.6179 - accuracy: 0.9838
# Epoch 29/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.6153 - accuracy: 0.9838
# Epoch 30/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.6124 - accuracy: 0.9853
# Epoch 31/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.6141 - accuracy: 0.9617
# Epoch 32/10000
# 678/678 [==============================] - 0s 141us/step - loss: 0.6164 - accuracy: 0.9366
# Epoch 33/10000
# 678/678 [==============================] - 0s 138us/step - loss: 0.6051 - accuracy: 0.9823
# Epoch 34/10000
# 678/678 [==============================] - 0s 163us/step - loss: 0.6034 - accuracy: 0.9779
# Epoch 35/10000
# 678/678 [==============================] - 0s 99us/step - loss: 0.6014 - accuracy: 0.9749
# Epoch 36/10000
# 678/678 [==============================] - 0s 105us/step - loss: 0.5996 - accuracy: 0.9720
# Epoch 37/10000
# 678/678 [==============================] - 0s 119us/step - loss: 0.5986 - accuracy: 0.9646
# Epoch 38/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.5966 - accuracy: 0.9631
# Epoch 39/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.5942 - accuracy: 0.9631
# Epoch 40/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.5905 - accuracy: 0.9690
# Epoch 41/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.5869 - accuracy: 0.9749
# Epoch 42/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.5833 - accuracy: 0.9794
# Epoch 43/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.5798 - accuracy: 0.9838
# Epoch 44/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.5762 - accuracy: 0.9882
# Epoch 45/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.5738 - accuracy: 0.9882
# Epoch 46/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.5710 - accuracy: 0.9897
# Epoch 47/10000
# 678/678 [==============================] - 0s 99us/step - loss: 0.5685 - accuracy: 0.9897
# Epoch 48/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.5661 - accuracy: 0.9897
# Epoch 49/10000
# 678/678 [==============================] - 0s 99us/step - loss: 0.5637 - accuracy: 0.9897
# Epoch 50/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.5613 - accuracy: 0.9897
# Epoch 51/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.5590 - accuracy: 0.9897
# Epoch 52/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.5565 - accuracy: 0.9897
# Epoch 53/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.5543 - accuracy: 0.9897
# Epoch 54/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.5515 - accuracy: 0.9912
# Epoch 55/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.5492 - accuracy: 0.9912
# Epoch 56/10000
# 678/678 [==============================] - 0s 104us/step - loss: 0.5469 - accuracy: 0.9912
# Epoch 57/10000
# 678/678 [==============================] - 0s 107us/step - loss: 0.5441 - accuracy: 0.9926
# Epoch 58/10000
# 678/678 [==============================] - 0s 181us/step - loss: 0.5423 - accuracy: 0.9912
# Epoch 59/10000
# 678/678 [==============================] - 0s 130us/step - loss: 0.5400 - accuracy: 0.9912
# Epoch 60/10000
# 678/678 [==============================] - 0s 127us/step - loss: 0.5375 - accuracy: 0.9926
# Epoch 61/10000
# 678/678 [==============================] - 0s 88us/step - loss: 0.5356 - accuracy: 0.9912
# Epoch 62/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.5328 - accuracy: 0.9926
# Epoch 63/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.5303 - accuracy: 0.9941
# Epoch 64/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.5279 - accuracy: 0.9941
# Epoch 65/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.5257 - accuracy: 0.9941
# Epoch 66/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.5236 - accuracy: 0.9941
# Epoch 67/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.5210 - accuracy: 0.9956
# Epoch 68/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.5192 - accuracy: 0.9941
# Epoch 69/10000
# 678/678 [==============================] - 0s 95us/step - loss: 0.5165 - accuracy: 0.9956
# Epoch 70/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.5144 - accuracy: 0.9956
# Epoch 71/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.5124 - accuracy: 0.9956
# Epoch 72/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.5102 - accuracy: 0.9956
# Epoch 73/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.5081 - accuracy: 0.9956
# Epoch 74/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.5060 - accuracy: 0.9956
# Epoch 75/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.5034 - accuracy: 0.9971
# Epoch 76/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.5018 - accuracy: 0.9956
# Epoch 77/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.4999 - accuracy: 0.9956
# Epoch 78/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.4973 - accuracy: 0.9971
# Epoch 79/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.4956 - accuracy: 0.9956
# Epoch 80/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.4937 - accuracy: 0.9956
# Epoch 81/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.4913 - accuracy: 0.9971
# Epoch 82/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.4893 - accuracy: 0.9971
# Epoch 83/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.4873 - accuracy: 0.9971
# Epoch 84/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.4853 - accuracy: 0.9971
# Epoch 85/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.4831 - accuracy: 0.9971
# Epoch 86/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.4811 - accuracy: 0.9971
# Epoch 87/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.4793 - accuracy: 0.9971
# Epoch 88/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.4772 - accuracy: 0.9971
# Epoch 89/10000
# 678/678 [==============================] - 0s 105us/step - loss: 0.4756 - accuracy: 0.9971
# Epoch 90/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.4729 - accuracy: 0.9985
# Epoch 91/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.4711 - accuracy: 0.9985
# Epoch 92/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.4693 - accuracy: 0.9985
# Epoch 93/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.4679 - accuracy: 0.9971
# Epoch 94/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.4660 - accuracy: 0.9971
# Epoch 95/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.4637 - accuracy: 0.9985
# Epoch 96/10000
# 678/678 [==============================] - 0s 105us/step - loss: 0.4618 - accuracy: 0.9985
# Epoch 97/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.4598 - accuracy: 0.9985
# Epoch 98/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.4581 - accuracy: 0.9985
# Epoch 99/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.4564 - accuracy: 0.9985
# Epoch 100/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.4544 - accuracy: 0.9985
# Epoch 101/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.4526 - accuracy: 0.9985
# Epoch 102/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.4508 - accuracy: 0.9985
# Epoch 103/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.4490 - accuracy: 0.9985
# Epoch 104/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.4473 - accuracy: 0.9985
# Epoch 105/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.4455 - accuracy: 0.9985
# Epoch 106/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.4439 - accuracy: 0.9985
# Epoch 107/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.4422 - accuracy: 0.9985
# Epoch 108/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.4403 - accuracy: 0.9985
# Epoch 109/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.4386 - accuracy: 0.9985
# Epoch 110/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.4369 - accuracy: 0.9985
# Epoch 111/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.4353 - accuracy: 0.9985
# Epoch 112/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.4336 - accuracy: 0.9985
# Epoch 113/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.4319 - accuracy: 0.9985
# Epoch 114/10000
# 678/678 [==============================] - 0s 121us/step - loss: 0.4303 - accuracy: 0.9985
# Epoch 115/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.4286 - accuracy: 0.9985
# Epoch 116/10000
# 678/678 [==============================] - 0s 95us/step - loss: 0.4270 - accuracy: 0.9985
# Epoch 117/10000
# 678/678 [==============================] - 0s 91us/step - loss: 0.4253 - accuracy: 0.9985
# Epoch 118/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.4237 - accuracy: 0.9985
# Epoch 119/10000
# 678/678 [==============================] - 0s 95us/step - loss: 0.4221 - accuracy: 0.9985
# Epoch 120/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.4205 - accuracy: 0.9985
# Epoch 121/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.4188 - accuracy: 0.9985
# Epoch 122/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.4172 - accuracy: 0.9985
# Epoch 123/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.4155 - accuracy: 0.9985
# Epoch 124/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.4146 - accuracy: 0.9971
# Epoch 125/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.4125 - accuracy: 0.9985
# Epoch 126/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.4110 - accuracy: 0.9985
# Epoch 127/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.4093 - accuracy: 0.9985
# Epoch 128/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.4082 - accuracy: 0.9985
# Epoch 129/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.4064 - accuracy: 0.9985
# Epoch 130/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.4050 - accuracy: 0.9985
# Epoch 131/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.4034 - accuracy: 0.9985
# Epoch 132/10000
# 678/678 [==============================] - 0s 119us/step - loss: 0.4017 - accuracy: 0.9985
# Epoch 133/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.4001 - accuracy: 0.9985
# Epoch 134/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.3989 - accuracy: 0.9985
# Epoch 135/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.3966 - accuracy: 1.0000
# Epoch 136/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3954 - accuracy: 0.9985
# Epoch 137/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.3937 - accuracy: 1.0000
# Epoch 138/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.3930 - accuracy: 0.9985
# Epoch 139/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.3914 - accuracy: 0.9985
# Epoch 140/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.3891 - accuracy: 1.0000
# Epoch 141/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3876 - accuracy: 1.0000
# Epoch 142/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.3867 - accuracy: 0.9985
# Epoch 143/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.3847 - accuracy: 1.0000
# Epoch 144/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3832 - accuracy: 1.0000
# Epoch 145/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.3829 - accuracy: 0.9985
# Epoch 146/10000
# 678/678 [==============================] - 0s 108us/step - loss: 0.3806 - accuracy: 1.0000
# Epoch 147/10000
# 678/678 [==============================] - 0s 101us/step - loss: 0.3790 - accuracy: 1.0000
# Epoch 148/10000
# 678/678 [==============================] - 0s 132us/step - loss: 0.3786 - accuracy: 0.9985
# Epoch 149/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.3773 - accuracy: 0.9985
# Epoch 150/10000
# 678/678 [==============================] - 0s 88us/step - loss: 0.3759 - accuracy: 0.9985
# Epoch 151/10000
# 678/678 [==============================] - 0s 130us/step - loss: 0.3746 - accuracy: 0.9985
# Epoch 152/10000
# 678/678 [==============================] - 0s 127us/step - loss: 0.3732 - accuracy: 0.9985
# Epoch 153/10000
# 678/678 [==============================] - 0s 118us/step - loss: 0.3718 - accuracy: 0.9985
# Epoch 154/10000
# 678/678 [==============================] - 0s 109us/step - loss: 0.3714 - accuracy: 0.9971
# Epoch 155/10000
# 678/678 [==============================] - 0s 173us/step - loss: 0.3692 - accuracy: 0.9985
# Epoch 156/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.3678 - accuracy: 0.9985
# Epoch 157/10000
# 678/678 [==============================] - 0s 121us/step - loss: 0.3665 - accuracy: 0.9985
# Epoch 158/10000
# 678/678 [==============================] - 0s 102us/step - loss: 0.3640 - accuracy: 1.0000
# Epoch 159/10000
# 678/678 [==============================] - 0s 104us/step - loss: 0.3627 - accuracy: 1.0000
# Epoch 160/10000
# 678/678 [==============================] - 0s 115us/step - loss: 0.3614 - accuracy: 1.0000
# Epoch 161/10000
# 678/678 [==============================] - 0s 118us/step - loss: 0.3617 - accuracy: 0.9985
# Epoch 162/10000
# 678/678 [==============================] - 0s 132us/step - loss: 0.3591 - accuracy: 1.0000
# Epoch 163/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.3575 - accuracy: 1.0000
# Epoch 164/10000
# 678/678 [==============================] - 0s 91us/step - loss: 0.3575 - accuracy: 0.9985
# Epoch 165/10000
# 678/678 [==============================] - 0s 112us/step - loss: 0.3574 - accuracy: 0.9971
# Epoch 166/10000
# 678/678 [==============================] - 0s 122us/step - loss: 0.3561 - accuracy: 0.9971
# Epoch 167/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.3549 - accuracy: 0.9971
# Epoch 168/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.3539 - accuracy: 0.9971
# Epoch 169/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.3511 - accuracy: 0.9985
# Epoch 170/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.3507 - accuracy: 0.9971
# Epoch 171/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.3486 - accuracy: 0.9985
# Epoch 172/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.3474 - accuracy: 0.9985
# Epoch 173/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3462 - accuracy: 0.9985
# Epoch 174/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.3451 - accuracy: 0.9985
# Epoch 175/10000
# 678/678 [==============================] - 0s 102us/step - loss: 0.3437 - accuracy: 0.9985
# Epoch 176/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.3425 - accuracy: 0.9985
# Epoch 177/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.3414 - accuracy: 0.9985
# Epoch 178/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.3402 - accuracy: 0.9985
# Epoch 179/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.3390 - accuracy: 0.9985
# Epoch 180/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.3378 - accuracy: 0.9985
# Epoch 181/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.3363 - accuracy: 0.9985
# Epoch 182/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.3353 - accuracy: 0.9985
# Epoch 183/10000
# 678/678 [==============================] - 0s 91us/step - loss: 0.3341 - accuracy: 0.9985
# Epoch 184/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.3331 - accuracy: 0.9985
# Epoch 185/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.3316 - accuracy: 1.0000
# Epoch 186/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3309 - accuracy: 0.9985
# Epoch 187/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.3292 - accuracy: 0.9985
# Epoch 188/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.3279 - accuracy: 1.0000
# Epoch 189/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.3265 - accuracy: 1.0000
# Epoch 190/10000
# 678/678 [==============================] - 0s 104us/step - loss: 0.3251 - accuracy: 1.0000
# Epoch 191/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.3243 - accuracy: 1.0000
# Epoch 192/10000
# 678/678 [==============================] - 0s 92us/step - loss: 0.3228 - accuracy: 1.0000
# Epoch 193/10000
# 678/678 [==============================] - 0s 105us/step - loss: 0.3216 - accuracy: 1.0000
# Epoch 194/10000
# 678/678 [==============================] - 0s 98us/step - loss: 0.3207 - accuracy: 1.0000
# Epoch 195/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.3193 - accuracy: 1.0000
# Epoch 196/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.3182 - accuracy: 1.0000
# Epoch 197/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.3171 - accuracy: 1.0000
# Epoch 198/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.3160 - accuracy: 1.0000
# Epoch 199/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.3149 - accuracy: 1.0000
# Epoch 200/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3138 - accuracy: 1.0000
# Epoch 201/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.3128 - accuracy: 1.0000
# Epoch 202/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3117 - accuracy: 1.0000
# Epoch 203/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.3106 - accuracy: 1.0000
# Epoch 204/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.3111 - accuracy: 0.9985
# Epoch 205/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.3085 - accuracy: 1.0000
# Epoch 206/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.3075 - accuracy: 1.0000
# Epoch 207/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.3064 - accuracy: 1.0000
# Epoch 208/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.3054 - accuracy: 1.0000
# Epoch 209/10000
# 678/678 [==============================] - 0s 89us/step - loss: 0.3043 - accuracy: 1.0000
# Epoch 210/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.3033 - accuracy: 1.0000
# Epoch 211/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.3023 - accuracy: 1.0000
# Epoch 212/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.3012 - accuracy: 1.0000
# Epoch 213/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.3002 - accuracy: 1.0000
# Epoch 214/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.2992 - accuracy: 1.0000
# Epoch 215/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.2984 - accuracy: 1.0000
# Epoch 216/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.2972 - accuracy: 1.0000
# Epoch 217/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.2962 - accuracy: 1.0000
# Epoch 218/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.2952 - accuracy: 1.0000
# Epoch 219/10000
# 678/678 [==============================] - 0s 96us/step - loss: 0.2942 - accuracy: 1.0000
# Epoch 220/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.2948 - accuracy: 0.9985
# Epoch 221/10000
# 678/678 [==============================] - 0s 91us/step - loss: 0.2938 - accuracy: 0.9985
# Epoch 222/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.2929 - accuracy: 0.9985
# Epoch 223/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.2919 - accuracy: 0.9985
# Epoch 224/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.2909 - accuracy: 0.9985
# Epoch 225/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.2900 - accuracy: 0.9985
# Epoch 226/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2890 - accuracy: 0.9985
# Epoch 227/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.2881 - accuracy: 0.9985
# Epoch 228/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.2871 - accuracy: 0.9985
# Epoch 229/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.2878 - accuracy: 0.9971
# Epoch 230/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2853 - accuracy: 0.9985
# Epoch 231/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2843 - accuracy: 0.9985
# Epoch 232/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.2851 - accuracy: 0.9971
# Epoch 233/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.2825 - accuracy: 0.9985
# Epoch 234/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.2816 - accuracy: 0.9985
# Epoch 235/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.2809 - accuracy: 0.9985
# Epoch 236/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.2798 - accuracy: 0.9985
# Epoch 237/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2789 - accuracy: 0.9985
# Epoch 238/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.2780 - accuracy: 0.9985
# Epoch 239/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.2771 - accuracy: 0.9985
# Epoch 240/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2745 - accuracy: 1.0000
# Epoch 241/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.2753 - accuracy: 0.9985
# Epoch 242/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.2728 - accuracy: 1.0000
# Epoch 243/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2719 - accuracy: 1.0000
# Epoch 244/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2721 - accuracy: 0.9985
# Epoch 245/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2704 - accuracy: 1.0000
# Epoch 246/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.2693 - accuracy: 1.0000
# Epoch 247/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.2684 - accuracy: 1.0000
# Epoch 248/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2675 - accuracy: 1.0000
# Epoch 249/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.2667 - accuracy: 1.0000
# Epoch 250/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.2658 - accuracy: 1.0000
# Epoch 251/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2667 - accuracy: 0.9985
# Epoch 252/10000
# 678/678 [==============================] - 0s 55us/step - loss: 0.2658 - accuracy: 0.9985
# Epoch 253/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.2650 - accuracy: 0.9985
# Epoch 254/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.2642 - accuracy: 0.9985
# Epoch 255/10000
# 678/678 [==============================] - 0s 101us/step - loss: 0.2635 - accuracy: 0.9985
# Epoch 256/10000
# 678/678 [==============================] - 0s 88us/step - loss: 0.2625 - accuracy: 0.9985
# Epoch 257/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.2617 - accuracy: 0.9985
# Epoch 258/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.2609 - accuracy: 0.9985
# Epoch 259/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2600 - accuracy: 0.9985
# Epoch 260/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2592 - accuracy: 0.9985
# Epoch 261/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2584 - accuracy: 0.9985
# Epoch 262/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2576 - accuracy: 0.9985
# Epoch 263/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2568 - accuracy: 0.9985
# Epoch 264/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.2560 - accuracy: 0.9985
# Epoch 265/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.2552 - accuracy: 0.9985
# Epoch 266/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.2544 - accuracy: 0.9985
# Epoch 267/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2537 - accuracy: 0.9985
# Epoch 268/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.2529 - accuracy: 0.9985
# Epoch 269/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.2521 - accuracy: 0.9985
# Epoch 270/10000
# 678/678 [==============================] - 0s 117us/step - loss: 0.2513 - accuracy: 0.9985
# Epoch 271/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.2505 - accuracy: 0.9985
# Epoch 272/10000
# 678/678 [==============================] - 0s 127us/step - loss: 0.2498 - accuracy: 0.9985
# Epoch 273/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.2490 - accuracy: 0.9985
# Epoch 274/10000
# 678/678 [==============================] - 0s 108us/step - loss: 0.2483 - accuracy: 0.9985
# Epoch 275/10000
# 678/678 [==============================] - 0s 102us/step - loss: 0.2475 - accuracy: 0.9985
# Epoch 276/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.2467 - accuracy: 0.9985
# Epoch 277/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.2460 - accuracy: 0.9985
# Epoch 278/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.2452 - accuracy: 0.9985
# Epoch 279/10000
# 678/678 [==============================] - 0s 62us/step - loss: 0.2445 - accuracy: 0.9985
# Epoch 280/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.2438 - accuracy: 0.9985
# Epoch 281/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.2430 - accuracy: 0.9985
# Epoch 282/10000
# 678/678 [==============================] - 0s 59us/step - loss: 0.2423 - accuracy: 0.9985
# Epoch 283/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.2415 - accuracy: 0.9985
# Epoch 284/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.2408 - accuracy: 0.9985
# Epoch 285/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.2401 - accuracy: 0.9985
# Epoch 286/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.2394 - accuracy: 0.9985
# Epoch 287/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.2386 - accuracy: 0.9985
# Epoch 288/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.2379 - accuracy: 0.9985
# Epoch 289/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.2372 - accuracy: 0.9985
# Epoch 290/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.2365 - accuracy: 0.9985
# Epoch 291/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.2358 - accuracy: 0.9985
# Epoch 292/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.2351 - accuracy: 0.9985
# Epoch 293/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.2344 - accuracy: 0.9985
# Epoch 294/10000
# 678/678 [==============================] - 0s 137us/step - loss: 0.2337 - accuracy: 0.9985
# Epoch 295/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.2330 - accuracy: 0.9985
# Epoch 296/10000
# 678/678 [==============================] - 0s 98us/step - loss: 0.2323 - accuracy: 0.9985
# Epoch 297/10000
# 678/678 [==============================] - 0s 89us/step - loss: 0.2316 - accuracy: 0.9985
# Epoch 298/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.2309 - accuracy: 0.9985
# Epoch 299/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.2303 - accuracy: 0.9985
# Epoch 300/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.2296 - accuracy: 0.9985
# Epoch 301/10000
# 678/678 [==============================] - 0s 88us/step - loss: 0.2289 - accuracy: 0.9985
# Epoch 302/10000
# 678/678 [==============================] - 0s 104us/step - loss: 0.2282 - accuracy: 0.9985
# Epoch 303/10000
# 678/678 [==============================] - 0s 96us/step - loss: 0.2276 - accuracy: 0.9985
# Epoch 304/10000
# 678/678 [==============================] - 0s 89us/step - loss: 0.2269 - accuracy: 0.9985
# Epoch 305/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.2262 - accuracy: 0.9985
# Epoch 306/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.2256 - accuracy: 0.9985
# Epoch 307/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.2249 - accuracy: 0.9985
# Epoch 308/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.2242 - accuracy: 0.9985
# Epoch 309/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.2236 - accuracy: 0.9985
# Epoch 310/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.2229 - accuracy: 0.9985
# Epoch 311/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.2223 - accuracy: 0.9985
# Epoch 312/10000
# 678/678 [==============================] - 0s 117us/step - loss: 0.2216 - accuracy: 0.9985
# Epoch 313/10000
# 678/678 [==============================] - 0s 99us/step - loss: 0.2210 - accuracy: 0.9985
# Epoch 314/10000
# 678/678 [==============================] - 0s 114us/step - loss: 0.2204 - accuracy: 0.9985
# Epoch 315/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.2197 - accuracy: 0.9985
# Epoch 316/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.2172 - accuracy: 1.0000
# Epoch 317/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.2182 - accuracy: 0.9985
# Epoch 318/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.2157 - accuracy: 1.0000
# Epoch 319/10000
# 678/678 [==============================] - 0s 94us/step - loss: 0.2151 - accuracy: 1.0000
# Epoch 320/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.2147 - accuracy: 1.0000
# Epoch 321/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.2147 - accuracy: 1.0000
# Epoch 322/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.2132 - accuracy: 1.0000
# Epoch 323/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.2126 - accuracy: 1.0000
# Epoch 324/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.2120 - accuracy: 1.0000
# Epoch 325/10000
# 678/678 [==============================] - 0s 96us/step - loss: 0.2114 - accuracy: 1.0000
# Epoch 326/10000
# 678/678 [==============================] - 0s 89us/step - loss: 0.2108 - accuracy: 1.0000
# Epoch 327/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.2102 - accuracy: 1.0000
# Epoch 328/10000
# 678/678 [==============================] - 0s 89us/step - loss: 0.2096 - accuracy: 1.0000
# Epoch 329/10000
# 678/678 [==============================] - 0s 94us/step - loss: 0.2090 - accuracy: 1.0000
# Epoch 330/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.2102 - accuracy: 0.9985
# Epoch 331/10000
# 678/678 [==============================] - 0s 98us/step - loss: 0.2077 - accuracy: 1.0000
# Epoch 332/10000
# 678/678 [==============================] - 0s 117us/step - loss: 0.2072 - accuracy: 1.0000
# Epoch 333/10000
# 678/678 [==============================] - 0s 98us/step - loss: 0.2065 - accuracy: 1.0000
# Epoch 334/10000
# 678/678 [==============================] - 0s 111us/step - loss: 0.2060 - accuracy: 1.0000
# Epoch 335/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.2053 - accuracy: 1.0000
# Epoch 336/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.2047 - accuracy: 1.0000
# Epoch 337/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.2041 - accuracy: 1.0000
# Epoch 338/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.2035 - accuracy: 1.0000
# Epoch 339/10000
# 678/678 [==============================] - 0s 85us/step - loss: 0.2030 - accuracy: 1.0000
# Epoch 340/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.2024 - accuracy: 1.0000
# Epoch 341/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.2018 - accuracy: 1.0000
# Epoch 342/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.2012 - accuracy: 1.0000
# Epoch 343/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.2006 - accuracy: 1.0000
# Epoch 344/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.2001 - accuracy: 1.0000
# Epoch 345/10000
# 678/678 [==============================] - 0s 145us/step - loss: 0.1995 - accuracy: 1.0000
# Epoch 346/10000
# 678/678 [==============================] - 0s 187us/step - loss: 0.1989 - accuracy: 1.0000
# Epoch 347/10000
# 678/678 [==============================] - 0s 107us/step - loss: 0.1984 - accuracy: 1.0000
# Epoch 348/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.1978 - accuracy: 1.0000
# Epoch 349/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.1972 - accuracy: 1.0000
# Epoch 350/10000
# 678/678 [==============================] - 0s 98us/step - loss: 0.1967 - accuracy: 1.0000
# Epoch 351/10000
# 678/678 [==============================] - 0s 82us/step - loss: 0.1961 - accuracy: 1.0000
# Epoch 352/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1956 - accuracy: 1.0000
# Epoch 353/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1950 - accuracy: 1.0000
# Epoch 354/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1945 - accuracy: 1.0000
# Epoch 355/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1939 - accuracy: 1.0000
# Epoch 356/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.1934 - accuracy: 1.0000
# Epoch 357/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1928 - accuracy: 1.0000
# Epoch 358/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.1923 - accuracy: 1.0000
# Epoch 359/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.1917 - accuracy: 1.0000
# Epoch 360/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.1912 - accuracy: 1.0000
# Epoch 361/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.1913 - accuracy: 1.0000
# Epoch 362/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.1901 - accuracy: 1.0000
# Epoch 363/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.1896 - accuracy: 1.0000
# Epoch 364/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1891 - accuracy: 1.0000
# Epoch 365/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.1888 - accuracy: 1.0000
# Epoch 366/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.1901 - accuracy: 0.9985
# Epoch 367/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.1875 - accuracy: 1.0000
# Epoch 368/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1870 - accuracy: 1.0000
# Epoch 369/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.1868 - accuracy: 1.0000
# Epoch 370/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.1860 - accuracy: 1.0000
# Epoch 371/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.1854 - accuracy: 1.0000
# Epoch 372/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1849 - accuracy: 1.0000
# Epoch 373/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.1846 - accuracy: 1.0000
# Epoch 374/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.1839 - accuracy: 1.0000
# Epoch 375/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1834 - accuracy: 1.0000
# Epoch 376/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.1829 - accuracy: 1.0000
# Epoch 377/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.1824 - accuracy: 1.0000
# Epoch 378/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.1819 - accuracy: 1.0000
# Epoch 379/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.1814 - accuracy: 1.0000
# Epoch 380/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.1809 - accuracy: 1.0000
# Epoch 381/10000
# 678/678 [==============================] - 0s 68us/step - loss: 0.1804 - accuracy: 1.0000
# Epoch 382/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.1799 - accuracy: 1.0000
# Epoch 383/10000
# 678/678 [==============================] - 0s 94us/step - loss: 0.1794 - accuracy: 1.0000
# Epoch 384/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.1790 - accuracy: 1.0000
# Epoch 385/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.1785 - accuracy: 1.0000
# Epoch 386/10000
# 678/678 [==============================] - 0s 91us/step - loss: 0.1780 - accuracy: 1.0000
# Epoch 387/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.1775 - accuracy: 1.0000
# Epoch 388/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.1770 - accuracy: 1.0000
# Epoch 389/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.1765 - accuracy: 1.0000
# Epoch 390/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.1761 - accuracy: 1.0000
# Epoch 391/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.1756 - accuracy: 1.0000
# Epoch 392/10000
# 678/678 [==============================] - 0s 176us/step - loss: 0.1751 - accuracy: 1.0000
# Epoch 393/10000
# 678/678 [==============================] - 0s 157us/step - loss: 0.1746 - accuracy: 1.0000
# Epoch 394/10000
# 678/678 [==============================] - 0s 181us/step - loss: 0.1742 - accuracy: 1.0000
# Epoch 395/10000
# 678/678 [==============================] - 0s 179us/step - loss: 0.1737 - accuracy: 1.0000
# Epoch 396/10000
# 678/678 [==============================] - 0s 91us/step - loss: 0.1732 - accuracy: 1.0000
# Epoch 397/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.1728 - accuracy: 1.0000
# Epoch 398/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.1723 - accuracy: 1.0000
# Epoch 399/10000
# 678/678 [==============================] - 0s 89us/step - loss: 0.1719 - accuracy: 1.0000
# Epoch 400/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1714 - accuracy: 1.0000
# Epoch 401/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.1709 - accuracy: 1.0000
# Epoch 402/10000
# 678/678 [==============================] - 0s 65us/step - loss: 0.1705 - accuracy: 1.0000
# Epoch 403/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.1700 - accuracy: 1.0000
# Epoch 404/10000
# 678/678 [==============================] - 0s 75us/step - loss: 0.1696 - accuracy: 1.0000
# Epoch 405/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.1691 - accuracy: 1.0000
# Epoch 406/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.1687 - accuracy: 1.0000
# Epoch 407/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1682 - accuracy: 1.0000
# Epoch 408/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1678 - accuracy: 1.0000
# Epoch 409/10000
# 678/678 [==============================] - 0s 92us/step - loss: 0.1674 - accuracy: 1.0000
# Epoch 410/10000
# 678/678 [==============================] - 0s 92us/step - loss: 0.1669 - accuracy: 1.0000
# Epoch 411/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.1665 - accuracy: 1.0000
# Epoch 412/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.1660 - accuracy: 1.0000
# Epoch 413/10000
# 678/678 [==============================] - 0s 130us/step - loss: 0.1656 - accuracy: 1.0000
# Epoch 414/10000
# 678/678 [==============================] - 0s 83us/step - loss: 0.1652 - accuracy: 1.0000
# Epoch 415/10000
# 678/678 [==============================] - 0s 92us/step - loss: 0.1647 - accuracy: 1.0000
# Epoch 416/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1643 - accuracy: 1.0000
# Epoch 417/10000
# 678/678 [==============================] - 0s 73us/step - loss: 0.1639 - accuracy: 1.0000
# Epoch 418/10000
# 678/678 [==============================] - 0s 72us/step - loss: 0.1634 - accuracy: 1.0000
# Epoch 419/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.1630 - accuracy: 1.0000
# Epoch 420/10000
# 678/678 [==============================] - 0s 63us/step - loss: 0.1626 - accuracy: 1.0000
# Epoch 421/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.1622 - accuracy: 1.0000
# Epoch 422/10000
# 678/678 [==============================] - 0s 69us/step - loss: 0.1617 - accuracy: 1.0000
# Epoch 423/10000
# 678/678 [==============================] - 0s 102us/step - loss: 0.1613 - accuracy: 1.0000
# Epoch 424/10000
# 678/678 [==============================] - 0s 107us/step - loss: 0.1609 - accuracy: 1.0000
# Epoch 425/10000
# 678/678 [==============================] - 0s 98us/step - loss: 0.1605 - accuracy: 1.0000
# Epoch 426/10000
# 678/678 [==============================] - 0s 102us/step - loss: 0.1601 - accuracy: 1.0000
# Epoch 427/10000
# 678/678 [==============================] - 0s 101us/step - loss: 0.1597 - accuracy: 1.0000
# Epoch 428/10000
# 678/678 [==============================] - 0s 89us/step - loss: 0.1593 - accuracy: 1.0000
# Epoch 429/10000
# 678/678 [==============================] - 0s 98us/step - loss: 0.1588 - accuracy: 1.0000
# Epoch 430/10000
# 678/678 [==============================] - 0s 117us/step - loss: 0.1584 - accuracy: 1.0000
# Epoch 431/10000
# 678/678 [==============================] - 0s 157us/step - loss: 0.1580 - accuracy: 1.0000
# Epoch 432/10000
# 678/678 [==============================] - 0s 117us/step - loss: 0.1576 - accuracy: 1.0000
# Epoch 433/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1572 - accuracy: 1.0000
# Epoch 434/10000
# 678/678 [==============================] - 0s 105us/step - loss: 0.1568 - accuracy: 1.0000
# Epoch 435/10000
# 678/678 [==============================] - 0s 137us/step - loss: 0.1564 - accuracy: 1.0000
# Epoch 436/10000
# 678/678 [==============================] - 0s 86us/step - loss: 0.1560 - accuracy: 1.0000
# Epoch 437/10000
# 678/678 [==============================] - 0s 81us/step - loss: 0.1556 - accuracy: 1.0000
# Epoch 438/10000
# 678/678 [==============================] - 0s 66us/step - loss: 0.1552 - accuracy: 1.0000
# Epoch 439/10000
# 678/678 [==============================] - 0s 79us/step - loss: 0.1548 - accuracy: 1.0000
# Epoch 440/10000
# 678/678 [==============================] - 0s 124us/step - loss: 0.1544 - accuracy: 1.0000
# Epoch 441/10000
# 678/678 [==============================] - 0s 105us/step - loss: 0.1540 - accuracy: 1.0000
# Epoch 442/10000
# 678/678 [==============================] - 0s 78us/step - loss: 0.1537 - accuracy: 1.0000
# Epoch 443/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.1533 - accuracy: 1.0000
# Epoch 444/10000
# 678/678 [==============================] - 0s 60us/step - loss: 0.1529 - accuracy: 1.0000
# Epoch 445/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.1525 - accuracy: 1.0000
# Epoch 446/10000
# 678/678 [==============================] - 0s 95us/step - loss: 0.1521 - accuracy: 1.0000
# Epoch 447/10000
# 678/678 [==============================] - 0s 76us/step - loss: 0.1517 - accuracy: 1.0000
# Epoch 448/10000
# 678/678 [==============================] - 0s 58us/step - loss: 0.1513 - accuracy: 1.0000
# Epoch 449/10000
# 678/678 [==============================] - 0s 71us/step - loss: 0.1510 - accuracy: 1.0000
# Epoch 450/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.1506 - accuracy: 1.0000
# Epoch 451/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.1502 - accuracy: 1.0000
# Epoch 452/10000
# 678/678 [==============================] - 0s 56us/step - loss: 0.1498 - accuracy: 1.0000
# Epoch 453/10000
# ...
# 678/678 [==============================] - 0s 62us/step - loss: 1.7814e-04 - accuracy: 1.0000
# Epoch 9796/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7805e-04 - accuracy: 1.0000
# Epoch 9797/10000
# 678/678 [==============================] - 0s 68us/step - loss: 1.7796e-04 - accuracy: 1.0000
# Epoch 9798/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7787e-04 - accuracy: 1.0000
# Epoch 9799/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.7778e-04 - accuracy: 1.0000
# Epoch 9800/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7770e-04 - accuracy: 1.0000
# Epoch 9801/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.7761e-04 - accuracy: 1.0000
# Epoch 9802/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7752e-04 - accuracy: 1.0000
# Epoch 9803/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7743e-04 - accuracy: 1.0000
# Epoch 9804/10000
# 678/678 [==============================] - 0s 71us/step - loss: 1.7734e-04 - accuracy: 1.0000
# Epoch 9805/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7725e-04 - accuracy: 1.0000
# Epoch 9806/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7716e-04 - accuracy: 1.0000
# Epoch 9807/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7707e-04 - accuracy: 1.0000
# Epoch 9808/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.7698e-04 - accuracy: 1.0000
# Epoch 9809/10000
# 678/678 [==============================] - 0s 58us/step - loss: 1.7690e-04 - accuracy: 1.0000
# Epoch 9810/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7681e-04 - accuracy: 1.0000
# Epoch 9811/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7672e-04 - accuracy: 1.0000
# Epoch 9812/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7663e-04 - accuracy: 1.0000
# Epoch 9813/10000
# 678/678 [==============================] - 0s 50us/step - loss: 1.7654e-04 - accuracy: 1.0000
# Epoch 9814/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7645e-04 - accuracy: 1.0000
# Epoch 9815/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7637e-04 - accuracy: 1.0000
# Epoch 9816/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7628e-04 - accuracy: 1.0000
# Epoch 9817/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7619e-04 - accuracy: 1.0000
# Epoch 9818/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7610e-04 - accuracy: 1.0000
# Epoch 9819/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7601e-04 - accuracy: 1.0000
# Epoch 9820/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7592e-04 - accuracy: 1.0000
# Epoch 9821/10000
# 678/678 [==============================] - 0s 55us/step - loss: 1.7584e-04 - accuracy: 1.0000
# Epoch 9822/10000
# 678/678 [==============================] - 0s 73us/step - loss: 1.7575e-04 - accuracy: 1.0000
# Epoch 9823/10000
# 678/678 [==============================] - 0s 79us/step - loss: 1.7566e-04 - accuracy: 1.0000
# Epoch 9824/10000
# 678/678 [==============================] - 0s 59us/step - loss: 1.7557e-04 - accuracy: 1.0000
# Epoch 9825/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7549e-04 - accuracy: 1.0000
# Epoch 9826/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7540e-04 - accuracy: 1.0000
# Epoch 9827/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7531e-04 - accuracy: 1.0000
# Epoch 9828/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7522e-04 - accuracy: 1.0000
# Epoch 9829/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7513e-04 - accuracy: 1.0000
# Epoch 9830/10000
# 678/678 [==============================] - 0s 50us/step - loss: 1.7505e-04 - accuracy: 1.0000
# Epoch 9831/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7496e-04 - accuracy: 1.0000
# Epoch 9832/10000
# 678/678 [==============================] - 0s 56us/step - loss: 1.7487e-04 - accuracy: 1.0000
# Epoch 9833/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7478e-04 - accuracy: 1.0000
# Epoch 9834/10000
# 678/678 [==============================] - 0s 58us/step - loss: 1.7470e-04 - accuracy: 1.0000
# Epoch 9835/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7461e-04 - accuracy: 1.0000
# Epoch 9836/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7452e-04 - accuracy: 1.0000
# Epoch 9837/10000
# 678/678 [==============================] - 0s 50us/step - loss: 1.7443e-04 - accuracy: 1.0000
# Epoch 9838/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7435e-04 - accuracy: 1.0000
# Epoch 9839/10000
# 678/678 [==============================] - 0s 55us/step - loss: 1.7426e-04 - accuracy: 1.0000
# Epoch 9840/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7417e-04 - accuracy: 1.0000
# Epoch 9841/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7408e-04 - accuracy: 1.0000
# Epoch 9842/10000
# 678/678 [==============================] - 0s 91us/step - loss: 1.7400e-04 - accuracy: 1.0000
# Epoch 9843/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7391e-04 - accuracy: 1.0000
# Epoch 9844/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7382e-04 - accuracy: 1.0000
# Epoch 9845/10000
# 678/678 [==============================] - 0s 72us/step - loss: 1.7374e-04 - accuracy: 1.0000
# Epoch 9846/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7365e-04 - accuracy: 1.0000
# Epoch 9847/10000
# 678/678 [==============================] - 0s 58us/step - loss: 1.7356e-04 - accuracy: 1.0000
# Epoch 9848/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7348e-04 - accuracy: 1.0000
# Epoch 9849/10000
# 678/678 [==============================] - 0s 55us/step - loss: 1.7339e-04 - accuracy: 1.0000
# Epoch 9850/10000
# 678/678 [==============================] - 0s 56us/step - loss: 1.7330e-04 - accuracy: 1.0000
# Epoch 9851/10000
# 678/678 [==============================] - 0s 71us/step - loss: 1.7322e-04 - accuracy: 1.0000
# Epoch 9852/10000
# 678/678 [==============================] - 0s 55us/step - loss: 1.7313e-04 - accuracy: 1.0000
# Epoch 9853/10000
# 678/678 [==============================] - 0s 69us/step - loss: 1.7304e-04 - accuracy: 1.0000
# Epoch 9854/10000
# 678/678 [==============================] - 0s 71us/step - loss: 1.7296e-04 - accuracy: 1.0000
# Epoch 9855/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.7287e-04 - accuracy: 1.0000
# Epoch 9856/10000
# 678/678 [==============================] - 0s 75us/step - loss: 1.7278e-04 - accuracy: 1.0000
# Epoch 9857/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7270e-04 - accuracy: 1.0000
# Epoch 9858/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7261e-04 - accuracy: 1.0000
# Epoch 9859/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7252e-04 - accuracy: 1.0000
# Epoch 9860/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7244e-04 - accuracy: 1.0000
# Epoch 9861/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7235e-04 - accuracy: 1.0000
# Epoch 9862/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7226e-04 - accuracy: 1.0000
# Epoch 9863/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7218e-04 - accuracy: 1.0000
# Epoch 9864/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7209e-04 - accuracy: 1.0000
# Epoch 9865/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7201e-04 - accuracy: 1.0000
# Epoch 9866/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7192e-04 - accuracy: 1.0000
# Epoch 9867/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7183e-04 - accuracy: 1.0000
# Epoch 9868/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7175e-04 - accuracy: 1.0000
# Epoch 9869/10000
# 678/678 [==============================] - 0s 56us/step - loss: 1.7166e-04 - accuracy: 1.0000
# Epoch 9870/10000
# 678/678 [==============================] - 0s 56us/step - loss: 1.7158e-04 - accuracy: 1.0000
# Epoch 9871/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7149e-04 - accuracy: 1.0000
# Epoch 9872/10000
# 678/678 [==============================] - 0s 58us/step - loss: 1.7140e-04 - accuracy: 1.0000
# Epoch 9873/10000
# 678/678 [==============================] - 0s 59us/step - loss: 1.7132e-04 - accuracy: 1.0000
# Epoch 9874/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7123e-04 - accuracy: 1.0000
# Epoch 9875/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7115e-04 - accuracy: 1.0000
# Epoch 9876/10000
# 678/678 [==============================] - 0s 58us/step - loss: 1.7106e-04 - accuracy: 1.0000
# Epoch 9877/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7098e-04 - accuracy: 1.0000
# Epoch 9878/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7089e-04 - accuracy: 1.0000
# Epoch 9879/10000
# 678/678 [==============================] - 0s 52us/step - loss: 1.7080e-04 - accuracy: 1.0000
# Epoch 9880/10000
# 678/678 [==============================] - 0s 55us/step - loss: 1.7072e-04 - accuracy: 1.0000
# Epoch 9881/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7063e-04 - accuracy: 1.0000
# Epoch 9882/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7055e-04 - accuracy: 1.0000
# Epoch 9883/10000
# 678/678 [==============================] - 0s 76us/step - loss: 1.7046e-04 - accuracy: 1.0000
# Epoch 9884/10000
# 678/678 [==============================] - 0s 53us/step - loss: 1.7038e-04 - accuracy: 1.0000
# Epoch 9885/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.7029e-04 - accuracy: 1.0000
# Epoch 9886/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.7021e-04 - accuracy: 1.0000
# Epoch 9887/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.7012e-04 - accuracy: 1.0000
# Epoch 9888/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.7004e-04 - accuracy: 1.0000
# Epoch 9889/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6995e-04 - accuracy: 1.0000
# Epoch 9890/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.6987e-04 - accuracy: 1.0000
# Epoch 9891/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6978e-04 - accuracy: 1.0000
# Epoch 9892/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6970e-04 - accuracy: 1.0000
# Epoch 9893/10000
# 678/678 [==============================] - 0s 66us/step - loss: 1.6961e-04 - accuracy: 1.0000
# Epoch 9894/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6953e-04 - accuracy: 1.0000
# Epoch 9895/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6944e-04 - accuracy: 1.0000
# Epoch 9896/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6936e-04 - accuracy: 1.0000
# Epoch 9897/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6927e-04 - accuracy: 1.0000
# Epoch 9898/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6919e-04 - accuracy: 1.0000
# Epoch 9899/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6910e-04 - accuracy: 1.0000
# Epoch 9900/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6902e-04 - accuracy: 1.0000
# Epoch 9901/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.6893e-04 - accuracy: 1.0000
# Epoch 9902/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6885e-04 - accuracy: 1.0000
# Epoch 9903/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6876e-04 - accuracy: 1.0000
# Epoch 9904/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6868e-04 - accuracy: 1.0000
# Epoch 9905/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6860e-04 - accuracy: 1.0000
# Epoch 9906/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6851e-04 - accuracy: 1.0000
# Epoch 9907/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6843e-04 - accuracy: 1.0000
# Epoch 9908/10000
# 678/678 [==============================] - 0s 80us/step - loss: 1.6834e-04 - accuracy: 1.0000
# Epoch 9909/10000
# 678/678 [==============================] - 0s 65us/step - loss: 1.6826e-04 - accuracy: 1.0000
# Epoch 9910/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6817e-04 - accuracy: 1.0000
# Epoch 9911/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6809e-04 - accuracy: 1.0000
# Epoch 9912/10000
# 678/678 [==============================] - 0s 65us/step - loss: 1.6801e-04 - accuracy: 1.0000
# Epoch 9913/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.6792e-04 - accuracy: 1.0000
# Epoch 9914/10000
# 678/678 [==============================] - 0s 68us/step - loss: 1.6784e-04 - accuracy: 1.0000
# Epoch 9915/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.6775e-04 - accuracy: 1.0000
# Epoch 9916/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6767e-04 - accuracy: 1.0000
# Epoch 9917/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6759e-04 - accuracy: 1.0000
# Epoch 9918/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6750e-04 - accuracy: 1.0000
# Epoch 9919/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.6742e-04 - accuracy: 1.0000
# Epoch 9920/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6734e-04 - accuracy: 1.0000
# Epoch 9921/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.6725e-04 - accuracy: 1.0000
# Epoch 9922/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6717e-04 - accuracy: 1.0000
# Epoch 9923/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6708e-04 - accuracy: 1.0000
# Epoch 9924/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6700e-04 - accuracy: 1.0000
# Epoch 9925/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6692e-04 - accuracy: 1.0000
# Epoch 9926/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6683e-04 - accuracy: 1.0000
# Epoch 9927/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6675e-04 - accuracy: 1.0000
# Epoch 9928/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6667e-04 - accuracy: 1.0000
# Epoch 9929/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6658e-04 - accuracy: 1.0000
# Epoch 9930/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6650e-04 - accuracy: 1.0000
# Epoch 9931/10000
# 678/678 [==============================] - 0s 60us/step - loss: 1.6642e-04 - accuracy: 1.0000
# Epoch 9932/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6633e-04 - accuracy: 1.0000
# Epoch 9933/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6625e-04 - accuracy: 1.0000
# Epoch 9934/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6617e-04 - accuracy: 1.0000
# Epoch 9935/10000
# 678/678 [==============================] - 0s 63us/step - loss: 1.6608e-04 - accuracy: 1.0000
# Epoch 9936/10000
# 678/678 [==============================] - 0s 65us/step - loss: 1.6600e-04 - accuracy: 1.0000
# Epoch 9937/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6592e-04 - accuracy: 1.0000
# Epoch 9938/10000
# 678/678 [==============================] - 0s 62us/step - loss: 1.6583e-04 - accuracy: 1.0000
# Epoch 9939/10000

# %%
plot_loss(model_output, "Plot Loss", 0)

# %%
final_results = pd.DataFrame(cm_results, columns=('algo','TN','FP','FN','TP', 'lr', 'w1', 'w2', 'epochs', 'batch_size')) 
#sp = round((tn1 + tn2)/(tn1 + tn2 +fp2), 3)
#se = round(tp2/(tp2 + fn1 + fn2), 3)
final_results['SP'] = round(final_results['TN']/(final_results['TN'] + final_results['FP']), 3)
final_results['SE'] = round(final_results['TP']/(final_results['TP'] + final_results['FN']), 3)
final_results['Avg'] = (final_results['SP'] + final_results['SE'])/2

print(strat,OrigPct,TrainPct,TrainDownPct,TestPct)

filtered = final_results[~final_results.algo.str.contains('a', regex= True, na=False)]
sort = filtered.sort_values(filtered.columns[7], ascending = False)
print(sort)

sort.to_csv('results_lstm.csv', sep=',', mode='a', encoding='utf-8', header=True)

# %%
sort = final_results.sort_values(final_results.columns[5], ascending = False)
sort.to_csv('results_lstm.csv', sep=',', mode='a', encoding='utf-8', header=True)
print(sort)

# %% [markdown]
# <pre>
#
# So far cannot get avg of SP and SE above 50%
#
# 1) Adam is more consistent for optimization
# 2) Stratify doesn't make much difference, include it for consistency
# 3) lr needs to be less than 0.05, keep at 0.01
#
# 4) Try wts later
# 5) epochs
# 6) batch size
#
# Details:
#
# SGD vs Adam and Stratify vs No Stratify:
#
#     SGD with Stratify produces inconsistent results, lots of 0's in the confusion matrix, esp TP
#     Adam with stratify is much more consistent, almost always has some values in all 4 categories, and FP has less variation, even if TP count is still low (~1-3)
#
#     SGD with Stratify:
#
#                  algo     TN     FP   FN   TP    lr   w1   w2  epochs  batch_size  \
#     0    sequential_1  79719   5566  142    6  0.01  4.0  1.0      10           8
#     13  sequential_14  85202     83  148    0  0.01  4.0  1.0      10           8
#     23  sequential_24  85160    125  148    0  0.01  4.0  1.0      10           8
#     22  sequential_23  40018  45267   69   79  0.01  4.0  1.0      10           8
#     21  sequential_22  85279      6  148    0  0.01  4.0  1.0      10           8
#     20  sequential_21  84649    636  148    0  0.01  4.0  1.0      10           8
#     19  sequential_20  85221     64  148    0  0.01  4.0  1.0      10           8
#     18  sequential_19  85252     33  148    0  0.01  4.0  1.0      10           8
#
#
#     SGD without Stratify:
#
#                  algo     TN     FP   FN   TP    lr   w1   w2  epochs  batch_size  \
#     0    sequential_1  85216     77  140    0  0.01  4.0  1.0      10           8
#     13  sequential_14  85035    258  138    2  0.01  4.0  1.0      10           8
#     23  sequential_24  85255     38  139    1  0.01  4.0  1.0      10           8
#     22  sequential_23  83812   1481  138    2  0.01  4.0  1.0      10           8
#     21  sequential_22  84769    524  140    0  0.01  4.0  1.0      10           8
#     20  sequential_21  76723   8570  129   11  0.01  4.0  1.0      10           8
#     19  sequential_20  85146    147  139    1  0.01  4.0  1.0      10           8
#
#     ADAM with Stratify:
#
#                  algo     TN    FP   FN  TP    lr   w1   w2  epochs  batch_size  \
#     0    sequential_1  84840   445  147   1  0.01  4.0  1.0      10           8
#     13  sequential_14  84984   301  148   0  0.01  4.0  1.0      10           8
#     23  sequential_24  84613   672  148   0  0.01  4.0  1.0      10           8
#     22  sequential_23  84447   838  147   1  0.01  4.0  1.0      10           8
#     21  sequential_22  84386   899  148   0  0.01  4.0  1.0      10           8
#     20  sequential_21  85037   248  148   0  0.01  4.0  1.0      10           8
#     19  sequential_20  84207  1078  145   3  0.01  4.0  1.0      10           8
#     18  sequential_19  85001   284  148   0  0.01  4.0  1.0      10           8
#     17  sequential_18  84990   295  148   0  0.01  4.0  1.0      10           8
#     16  sequential_17  84863   422  148   0  0.01  4.0  1.0      10           8
#     15  sequential_16  84585   700  147   1  0.01  4.0  1.0      10           8
#     14  sequential_15  84728   557  148   0  0.01  4.0  1.0      10           8
#     12  sequential_13  84396   889  146   2  0.01  4.0  1.0      10           8
#     ADAM without Stratify:
#
#                  algo     TN    FP   FN  TP    lr   w1   w2  epochs  batch_size  \
#     0    sequential_1  84218  1055  159   1  0.01  4.0  1.0      10           8
#     13  sequential_14  85036   237  160   0  0.01  4.0  1.0      10           8
#     23  sequential_24  84721   552  159   1  0.01  4.0  1.0      10           8
#     22  sequential_23  84609   664  160   0  0.01  4.0  1.0      10           8
#     21  sequential_22  84730   543  160   0  0.01  4.0  1.0      10           8
#     20  sequential_21  85046   227  160   0  0.01  4.0  1.0      10           8
#     19  sequential_20  84771   502  158   2  0.01  4.0  1.0      10           8
#     18  sequential_19  84612   661  160   0  0.01  4.0  1.0      10           8
#     17  sequential_18  82808  2465  154   6  0.01  4.0  1.0      10           8
#     16  sequential_17  84382   891  159   1  0.01  4.0  1.0      10           8
#     15  sequential_16  84715   558  160   0  0.01  4.0  1.0      10           8
#     14  sequential_15  84879   394  160   0  0.01  4.0  1.0      10           8
#     12  sequential_13  85240    33  160   0  0.01  4.0  1.0      10           8
#     1    sequential_2  84906   367  160   0  0.01  4.0  1.0      10           8
#
# lr values (ADAM and Stratify): use value of 0.025
#
# need value less than 0.05 to show consistency in results
#
#              algo     TN     FP   FN   TP        lr   w1   w2  epochs  \
# 24  sequential_25  85285      0  148    0  0.100000  4.0  1.0      10
# 23  sequential_24  85285      0  148    0  0.100000  4.0  1.0      10
# 22  sequential_23  85285      0  148    0  0.100000  4.0  1.0      10
# 21  sequential_22      0  85285    0  148  0.100000  4.0  1.0      10
# 20  sequential_21      1  85284    0  148  0.100000  4.0  1.0      10
# 19  sequential_20  84877    408  144    4  0.075025  4.0  1.0      10
# 18  sequential_19  84508    777  144    4  0.075025  4.0  1.0      10
# 17  sequential_18      0  85285    0  148  0.075025  4.0  1.0      10
# 16  sequential_17  81305   3980  141    7  0.075025  4.0  1.0      10
# 15  sequential_16  84733    552  145    3  0.075025  4.0  1.0      10
# **** cutoff here
# 13  sequential_14  83804   1481  143    5  0.050050  4.0  1.0      10
# 14  sequential_15  83316   1969  143    5  0.050050  4.0  1.0      10
# 12  sequential_13  85011    274  147    1  0.050050  4.0  1.0      10
# 11  sequential_12  84644    641  144    4  0.050050  4.0  1.0      10
# 10  sequential_11  85131    154  147    1  0.050050  4.0  1.0      10
# 9   sequential_10  84520    765  145    3  0.025075  4.0  1.0      10
# 8    sequential_9  84118   1167  142    6  0.025075  4.0  1.0      10
# 7    sequential_8  84874    411  147    1  0.025075  4.0  1.0      10
# 6    sequential_7  84557    728  144    4  0.025075  4.0  1.0      10
# 5    sequential_6  84555    730  144    4  0.025075  4.0  1.0      10
# 1    sequential_2  85038    247  147    1  0.000100  4.0  1.0      10
# 4    sequential_5  85123    162  146    2  0.000100  4.0  1.0      10
# 3    sequential_4  85026    259  147    1  0.000100  4.0  1.0      10
# 2    sequential_3  84763    522  146    2  0.000100  4.0  1.0      10
# 0    sequential_1  84537    748  146    2  0.000100  4.0  1.0      10
#
#
#              algo     TN    FP   FN  TP        lr   w1   w2  epochs  \
# 24  sequential_25  84318   967  146   2  0.050000  4.0  1.0      10
# 23  sequential_24  85045   240  147   1  0.050000  4.0  1.0      10
# 22  sequential_23  84672   613  146   2  0.050000  4.0  1.0      10
# 21  sequential_22  82670  2615  142   6  0.050000  4.0  1.0      10
# 20  sequential_21  83087  2198  146   2  0.050000  4.0  1.0      10
# 19  sequential_20  84231  1054  148   0  0.037525  4.0  1.0      10
# 18  sequential_19  85006   279  148   0  0.037525  4.0  1.0      10
# 17  sequential_18  84610   675  148   0  0.037525  4.0  1.0      10
# 16  sequential_17  84759   526  148   0  0.037525  4.0  1.0      10
# 15  sequential_16  84522   763  148   0  0.037525  4.0  1.0      10
# 13  sequential_14  83834  1451  146   2  0.025050  4.0  1.0      10
# 14  sequential_15  83814  1471  146   2  0.025050  4.0  1.0      10
# 12  sequential_13  84764   521  148   0  0.025050  4.0  1.0      10
# 11  sequential_12  84809   476  147   1  0.025050  4.0  1.0      10
# 10  sequential_11  84723   562  147   1  0.025050  4.0  1.0      10
# 9   sequential_10  84879   406  148   0  0.012575  4.0  1.0      10
# 8    sequential_9  83464  1821  147   1  0.012575  4.0  1.0      10
# 7    sequential_8  84803   482  148   0  0.012575  4.0  1.0      10
# 6    sequential_7  82689  2596  144   4  0.012575  4.0  1.0      10
# 5    sequential_6  83254  2031  147   1  0.012575  4.0  1.0      10
# 1    sequential_2  84693   592  148   0  0.000100  4.0  1.0      10
# 4    sequential_5  85028   257  148   0  0.000100  4.0  1.0      10
# 3    sequential_4  84807   478  148   0  0.000100  4.0  1.0      10
# 2    sequential_3  84371   914  148   0  0.000100  4.0  1.0      10
# 0    sequential_1  84495   790  148   0  0.000100  4.0  1.0      10

# %%
print('finish')
